# %%
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer, BertForSequenceClassification, AdamW
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import csv
from transformers import BertTokenizer, BertForSequenceClassification
def load_model(model_path):
  # Load the trained model
  model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
  model.load_state_dict(torch.load(model_path, map_location=torch.device('cpu')))
  model.eval()
  return model
def predict(model, tokenizer, text):
  # Tokenize the input text
  encoding = tokenizer.encode_plus(
      text,
      add_special_tokens=True,
      max_length=128,
      return_token_type_ids=False,
      padding='max_length',
      truncation=True,
      return_attention_mask=True,
      return_tensors='pt',
  )

  # Move the input to the same device as the model
  input_ids = encoding['input_ids'].to(model.device)
  attention_mask = encoding['attention_mask'].to(model.device)

  # Perform inference
  with torch.no_grad():
      outputs = model(input_ids, attention_mask=attention_mask)
      _, prediction = torch.max(outputs.logits, dim=1)

  return prediction.item()
# Load the model and tokenizer
model_path = 'feedback_sentiment_model.pth'  
model = load_model(model_path)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')# Read the TSV file manually
data = []
with open('/Users/aaravnoronha/Desktop/Student Feedback Data - Training Model.tsv', 'r', encoding='utf-8') as file:
  tsv_reader = csv.reader(file, delimiter='\t')
  headers = next(tsv_reader)  # Read the header row
  for row in tsv_reader:
      if len(row) >= 2:  # Ensure we have at least Rating and Feedback
          data.append({'Rating': row[0], 'Feedback': row[1]})

# Convert to DataFrame
df = pd.DataFrame(data)

def is_positive(rating):
  try:
      return float(rating) >= 3.0
  except ValueError:
      return False

print("Predictions for all student feedback entries:")
total = 0
correct = 0
for i, row in df.iterrows():
  rating = row['Rating']
  feedback = row['Feedback']
  
  if pd.isna(feedback) or feedback.strip() == '':
      continue
  
  actual_sentiment = "Positive" if is_positive(rating) else "Negative"
  predicted_sentiment = "Positive" if predict(model, tokenizer, str(feedback)) == 1 else "Negative"
  
  print(f"Feedback {i+1}:")
  print(f"  Rating: {rating}")
  print(f"  Feedback: {feedback}")
  print(f"  Actual Sentiment: {actual_sentiment}")
  print(f"  Predicted Sentiment: {predicted_sentiment}")
  print()

  total += 1
  if (actual_sentiment == "Positive" and predicted_sentiment == "Positive") or \
     (actual_sentiment == "Negative" and predicted_sentiment == "Negative"):
      correct += 1

accuracy = correct / total if total > 0 else 0
print(f"Overall Accuracy: {accuracy:.2f}")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Predictions for all student feedback entries:
# Feedback 1:
#   Rating: 3
#   Feedback: Awesome class
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 2:
#   Rating: 3
#   Feedback: Awesome class.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 3:
#   Rating: 3.5
#   Feedback: Great Class!!
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 4:
#   Rating: 3
#   Feedback: great class
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 5:
#   Rating: 0.5
#   Feedback: nobody showed up.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 6:
#   Rating: 1.5
#   Feedback: Mentor wasn't present for the class. Hoping to see mentor for the next booked class :)
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 7:
#   Rating: 0.5
#   Feedback: No one show up for class today
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 8:
#   Rating: 1
#   Feedback: Quality could not hear her
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 9:
#   Rating: 2.5
#   Feedback: It has been too long since I did beginners. This was too hard for me
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 10:
#   Rating: 1
#   Feedback: Your app and instructions aren’t clear. Confusing!
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 11:
#   Rating: 1
#   Feedback: as I am still learning yoga sometimes I am not familiar  with pose names instead of just saying pose name it would be better if teacher explains it example chaturnanga and say it like right leg back and left leg back. overall not happy with the class had to leave in middle as I felt no proper explanation.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 12:
#   Rating: 2
#   Feedback: before and during the asanas there is a lack of flow and the instructions are missing at most of the times. Should have been more in sync so I could understand the asanas better
#   Actual Sentiment: Negative
#   Predicted Sentiment: Positive
#
# Feedback 13:
#   Rating: 2.5
#   Feedback:  I had some difficulty  understanding  what to do. Due to the placement of my camera...I feel so tired,stiff and frustrated during the pace of the class. However,I feel motivated to learn more,stretch more,breath and focus better. Thank you!
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 14:
#   Rating: 3
#   Feedback: more detailed instructions needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 15:
#   Rating: 1
#   Feedback: more relaxed pleasant teacher
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 16:
#   Rating: 3
#   Feedback: more feedback on how well I was doing and what to improve
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 17:
#   Rating: 0.5
#   Feedback: Request the instructor to join the class on time
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 18:
#   Rating: 3.5
#   Feedback: Good
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 19:
#   Rating: 0.5
#   Feedback: No class, instructor did not come. waited for 20 mins
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 20:
#   Rating: 3.5
#   Feedback: Great class. If possible instructor can wear headphones to reduce background noise, and white noise.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 21:
#   Rating: 3.5
#   Feedback: extend couple of seconds to hold the pose
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 22:
#   Rating: 3
#   Feedback: No interaction for Q&As at the end
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 23:
#   Rating: 0.5
#   Feedback: couldn't hear anything latter vide disappeared too....
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 24:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 25:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 26:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 27:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 28:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 29:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 30:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 31:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 32:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 33:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 34:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 35:
#   Rating: 3
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 36:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 37:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 38:
#   Rating: 2
#   Feedback: It was tough for me
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 39:
#   Rating: 4
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 40:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 41:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 42:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 43:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 44:
#   Rating: 4
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 45:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 46:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 47:
#   Rating: 4.5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 48:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 49:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 50:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 51:
#   Rating: 4
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 52:
#   Rating: 5
#   Feedback: Excellent class and excellent at working with student who has medical limitations while making sure the class was not interested
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 53:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 54:
#   Rating: 0.5
#   Feedback: Wasn’t audible, it was more of yoga than meditation and pranayama
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 55:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 56:
#   Rating: 0.5
#   Feedback: Couldn’t hear a thing
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 57:
#   Rating: 4.5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 58:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 59:
#   Rating: 0.5
#   Feedback: bad internet
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 60:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 61:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 62:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 63:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 64:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 65:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 66:
#   Rating: 3.5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 67:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 68:
#   Rating: 3.5
#   Feedback: Good class. Would benefit from more precise verbal cues all along.Always need to look at screen due to lack of clear and precise verbal cues. Music at the end was overwhelmingly loud.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 69:
#   Rating: 5
#   Feedback: Other
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 70:
#   Rating: 4.5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 71:
#   Rating: 4
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 72:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 73:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 74:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 75:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 76:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 77:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 78:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 79:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 80:
#   Rating: 4.5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 81:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 82:
#   Rating: 4
#   Feedback: Other
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 83:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 84:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 85:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 86:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 87:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 88:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 89:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 90:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 91:
#   Rating: 5
#   Feedback: I loved the class with Sanjana, I am so impressed she explained every single aasana in details before letting us try.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 92:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 93:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 94:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 95:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 96:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 97:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 98:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 99:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 100:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 101:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 102:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 103:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 104:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 105:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 106:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 107:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 108:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 109:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 110:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 111:
#   Rating: 4.5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 112:
#   Rating: 4.5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 113:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 114:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 115:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 116:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 117:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 118:
#   Rating: 4.5
#   Feedback: Coach arrives on time and gives very clear instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 119:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 120:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 121:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 122:
#   Rating: 3
#   Feedback: I wasn’t able to join from laptop, why?
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 123:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 124:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 125:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 126:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 127:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 128:
#   Rating: 1
#   Feedback: Video and audio pasued, due to bad connection. need to drop off the class.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 129:
#   Rating: 1
#   Feedback: The video was keep going ON and OFF.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 130:
#   Rating: 5
#   Feedback: Teacher Gave Clear instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 131:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 132:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 133:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 134:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 135:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 136:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 137:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 138:
#   Rating: 5
#   Feedback: Avanti is amazing
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 139:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 140:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 141:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 142:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 143:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 144:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 145:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 146:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 147:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 148:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 149:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 150:
#   Rating: 2.5
#   Feedback: volme was very low so  no clear instructions
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 151:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 152:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 153:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 154:
#   Rating: 0.5
#   Feedback: Bad network at teacher's side, not able to follow the instructions as the video is paused and the voice is cracking.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 155:
#   Rating: 2.5
#   Feedback: teacher was unavailable for 15 min in class due to network glitch, else everything is good
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 156:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 157:
#   Rating: 4.5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 158:
#   Rating: 0.5
#   Feedback: No instructor
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 159:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 160:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 161:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 162:
#   Rating: 0.5
#   Feedback: There was no teacher, we waited for 15 mins and disconnected
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 163:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 164:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 165:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 166:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 167:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 168:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 169:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 170:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 171:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 172:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 173:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 174:
#   Rating: 4
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 175:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 176:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 177:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 178:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 179:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 180:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 181:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 182:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 183:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 184:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 185:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 186:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 187:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 188:
#   Rating: 4.5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 189:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 190:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 191:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 192:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 193:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 194:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 195:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 196:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 197:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 198:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 199:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 200:
#   Rating: 3.5
#   Feedback: Great experience
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 201:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 202:
#   Rating: 3.5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 203:
#   Rating: 3.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 204:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 205:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 206:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 207:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 208:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 209:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 210:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 211:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 212:
#   Rating: 2
#   Feedback: few tips and alternates for the beginners would help, because I have shoulder issues and I couldn't do few and didn't continue and complete
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 213:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 214:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 215:
#   Rating: 0.5
#   Feedback: The class started 10 min late. But ended on time. I prefer a restorative class similar to Vineet or Vikram. We are doing our regular exercises but slowly. Today the class was super slow. I do not feel I have done any exercise at all. Very poor experience.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 216:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 217:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 218:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 219:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 220:
#   Rating: 1
#   Feedback: No class
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 221:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 222:
#   Rating: 1
#   Feedback: could not log in and could not open the camera.  kept getting message something is wrong
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 223:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 224:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 225:
#   Rating: 1
#   Feedback: The teacher did not show up for the class
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 226:
#   Rating: 5
#   Feedback: A wonderful class to start with. Veena was so welcoming.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 227:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 228:
#   Rating: 3.5
#   Feedback: an explanation of what the breathing is doing and why we do it.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 229:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 230:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 231:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 232:
#   Rating: 0.5
#   Feedback: could'nt see video at all. voice was also breaking.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 233:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 234:
#   Rating: 1
#   Feedback: No one showed up for claass
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 235:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 236:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 237:
#   Rating: 4.5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 238:
#   Rating: 4.5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 239:
#   Rating: 4.5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 240:
#   Rating: 0.5
#   Feedback: [6:03 AM, 11/28/2022] Anita: Ia logged in. But no one is here [6:03 AM, 11/28/2022] Anita: I am [6:15 AM, 11/28/2022] Anita: I think, the link that you gave me, it takes me to my previous class when I log in from my phone now, as it says the class has ended.  I am logged in successfully from laptop. But now I think it might  be the previous link too as I had logged in before my current class time it allowed me in. I was supposed to join the previous class which I did complete successfully. So do I have the wrong link? [6:19 AM, 11/28/2022] Anita: I also called +1(315)9029642. And the lady told me that she will call in 2 mins. But no reply. Haven't heard from her or from anyone on whatsapp either. [6:20 AM, 11/28/2022] Anita: I am leaving the online session now as it's past 20 mins of my 30 mins class.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 241:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 242:
#   Rating: 3.5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 243:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 244:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 245:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 246:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 247:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 248:
#   Rating: 2.5
#   Feedback: Video kept disconnecting
#   Actual Sentiment: Negative
#   Predicted Sentiment: Positive
#
# Feedback 249:
#   Rating: 2.5
#   Feedback: video keeps stopping
#   Actual Sentiment: Negative
#   Predicted Sentiment: Positive
#
# Feedback 250:
#   Rating: 3.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 251:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 252:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 253:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 254:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 255:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 256:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 257:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 258:
#   Rating: 3.5
#   Feedback: The teacher is great but her audio is not clear. It happened in a previous class as well and few others also experienced the same issue.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 259:
#   Rating: 1.5
#   Feedback: Call kept hanging. It was very annoying. Unable to login to call via the app either
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 260:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 261:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 262:
#   Rating: 4.5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 263:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 264:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 265:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 266:
#   Rating: 3
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 267:
#   Rating: 3.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 268:
#   Rating: 0.5
#   Feedback: I never book class with her she , I don't want waste my time. I book class with her few time and I was so disappointed.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 269:
#   Rating: 0.5
#   Feedback: looks like a trch problem class did not happen
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 270:
#   Rating: 0.5
#   Feedback: The instructor was a no-show. I waited 10 minutes and then left.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 271:
#   Rating: 1
#   Feedback: No one came to begin the class.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 272:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 273:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 274:
#   Rating: 4.5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 275:
#   Rating: 4
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 276:
#   Rating: 4.5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 277:
#   Rating: 3.5
#   Feedback: Audio is not consistently clear. Instructor is great!
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 278:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 279:
#   Rating: 0.5
#   Feedback: No sound
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 280:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 281:
#   Rating: 1
#   Feedback: I stop in the middle of my session  she talk to fast and she yelled.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 282:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 283:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 284:
#   Rating: 0.5
#   Feedback: She doesn't give clear instructions , I try to give her the benefit of the doubt , more then one time today I did leave the class she was going to fast and I think she didn't care if we doing the right move. I will never book class with her again.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 285:
#   Rating: 3.5
#   Feedback: Great yoga but wish my pants weren’t slipping down so much. I don’t really care I’m very body positive but anyone who looks back on the recording can see my Buttcrack and at one point when my pants slipped all the way down. Otherwise, loved the teacher and movements.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 286:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 287:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 288:
#   Rating: 4
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 289:
#   Rating: 3.5
#   Feedback: light music would help. Some chanting may have helped.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 290:
#   Rating: 5
#   Feedback: Excellent Teacher
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 291:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 292:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 293:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 294:
#   Rating: 4.5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 295:
#   Rating: 3.5
#   Feedback: Instructor moved alittle fast for beginners class.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 296:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 297:
#   Rating: 3
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 298:
#   Rating: 4.5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 299:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 300:
#   Rating: 3
#   Feedback: a short briefing session would have helped at the beginning of the class esp since it was a new session for me
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 301:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 302:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 303:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 304:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 305:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 306:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 307:
#   Rating: 3
#   Feedback: too many network issues
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 308:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 309:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 310:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 311:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 312:
#   Rating: 3
#   Feedback: I liked the class, but would have liked her to give me a little more feedback
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 313:
#   Rating: 3.5
#   Feedback: video screen was getting frozen
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 314:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 315:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 316:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 317:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 318:
#   Rating: 0.5
#   Feedback: Unfortunately I can’t hear the instructor I check my wi
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 319:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 320:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 321:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 322:
#   Rating: 3
#   Feedback: the class went too fast. would like some pranayam . as well as attention to beginners
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 323:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 324:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 325:
#   Rating: 1
#   Feedback: The teacher did not join. Hope all is well.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 326:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 327:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 328:
#   Rating: 4.5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 329:
#   Rating: 3
#   Feedback: I had to leave to take a business call.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 330:
#   Rating: 3
#   Feedback:  The internet was choppy. We lost the instructor for good 3-4 mins.. The instructor is great however the system needs improvement.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 331:
#   Rating: 4.5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 332:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 333:
#   Rating: 0.5
#   Feedback: waited till 5:10pm but instructor did not join.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 334:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 335:
#   Rating: 0.5
#   Feedback: The Mentor appear not being caring , I could not get answer from her at first few minutes of joining. She did not do anything which make me feel like part of the class.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 336:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 337:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 338:
#   Rating: 1
#   Feedback: Instructor wasn’t being very upfront about what we are going to do, so it was a little bit confusing. Dolma &!Sakshi explains and then asks us to do which makes it easier on what to expect. Pls bring their classes back.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 339:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 340:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 341:
#   Rating: 2
#   Feedback: Not clear enough instructions
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 342:
# ...
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 412:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 413:
#   Rating: 5
#   Feedback: is it possible to include breathing exercise as well?
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 414:
#   Rating: 5
#   Feedback: Great variations and perfect pace. Class was awesome. Gave clear instructions to both beginners and regular practitioners.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 415:
#   Rating: 4
#   Feedback: Voice clarity is not so good informed the instructor.same feedback from another attendee today
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 416:
#   Rating: 5
#   Feedback: Simply awesome
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 417:
#   Rating: 5
#   Feedback: Really liked the modification teacher took after the class i really feel fresh and full of energy.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 418:
#   Rating: 4
#   Feedback:  teacher couldve been more interactive, was speaking too fast especially in shvasana
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 419:
#   Rating: 5
#   Feedback:  Learned a lot of new stretches today and it was good and slow.   The only thing is that the teacher's audio becomes choppy and unclear when they are not facing the camera or lying down.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 420:
#   Rating: 5
#   Feedback: excellent deep strectches....must dom more often
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 421:
#   Rating: 5
#   Feedback: amazing session today
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 422:
#   Rating: 4
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 423:
#   Rating: 4
#   Feedback: Voice is shaky and others also felt the same
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 424:
#   Rating: 5
#   Feedback: Pace of the instructions were too fast
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 425:
#   Rating: 5
#   Feedback: Awesome
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 426:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 427:
#   Rating: 5
#   Feedback: Covering class for entire 60 minutes will be helpful.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 428:
#   Rating: 5
#   Feedback: Shwetha is very patient and guides the class well.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 429:
#   Rating: 5
#   Feedback:  Vineeth sir is not only master of his art which is Yoga, but also master of teaching methodology when it comes to imparting his knowledge. His instructions are crystal clear and makes me feel comfortable. I prefer to practice only under his guidance. I wish he would take some early morning classes from the time slots between 6am - 9am
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 430:
#   Rating: 5
#   Feedback: Coach paid attention to everyone..
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 431:
#   Rating: 5
#   Feedback:  But your app is not working, in iOS.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Negative
#
# Feedback 432:
#   Rating: 5
#   Feedback: Beautiful relaxation/meditation & chanti.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 433:
#   Rating: 5
#   Feedback:  Love the music in the background as well, it helps
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 434:
#   Rating: 4
#   Feedback: the tempo of the music in shvasana was very fast. cannot relax in it or go within.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 435:
#   Rating: 4
#   Feedback:  Class is good , no doubt about it. However I noticed few things in today's class and sharing here...it will be great if instructor give small breaks or child pose asanas in bw it get our breath back ! Also not sure,  highlighting one person through out the classis comfortable to that person and also to others ( not saying this out of jealousy) . Usually attendees look up for instructor and its totally fine if one person in class is performing good and highlighting for particular time for that asana . Whole class running on one person is like that person is taking class . It's my opinion. Apart from this I enjoyed the class and sequence . Again it's my personal opinion and not against with anyone .
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 436:
#   Rating: 5
#   Feedback: Very clear instruction
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 437:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 438:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 439:
#   Rating: 5
#   Feedback: Is it possible to include some breathing exercise as well?
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 440:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 441:
#   Rating: 5
#   Feedback:  Dolma is very patient and encouraging. I also like her selection of poses, they are challenging and I feel amazing after trying them.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 442:
#   Rating: 5
#   Feedback: Flexible schedules
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 443:
#   Rating: 4.5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 444:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 445:
#   Rating: 5
#   Feedback: Please have the relaxing session for atlease 5 mins like you did today
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 446:
#   Rating: 5
#   Feedback: awesome just awesome
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 447:
#   Rating: 5
#   Feedback:  Sound quality, barely audible.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 448:
#   Rating: 4
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 449:
#   Rating: 5
#   Feedback: Meghana is a fantastic coach. She will give corrections and direct me on the right path and Love working with her.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 450:
#   Rating: 1
#   Feedback:  For the new asanas, giving the instructions one time and moving ahead does not help. I was stuck most of this class and was sitting idle without knowing what to do. With a mix of seasoned practitioners and beginners, the class has to be conducted in such a way to allow everyone to progress. Instructions and demonstrations need to be repeated so we can pick up as we may not get the whole pose with one set of instructions. I felt so demotivated and deflated after the class.  Also, the quality and pace of the suryanamaskar should be considered over the quantity. Doing a fewer number of suryanamaskars, slower and keeping each pose for a few seconds should be considered, rather than many rounds. I am not sure why the variety of class offerings at 6am has reduced and is now a mix of intermediate and beginners. Also there are no weight loss or other options available at 6.
#   Actual Sentiment: Negative
#   Predicted Sentiment: Positive
#
# Feedback 451:
#   Rating: 5
#   Feedback: What a difference from yesterday! We were given clear instructions and demonstrations.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 452:
#   Rating: 3
#   Feedback:  teacher practiced for just 49 minutes maximum...he ,mentioned its a 90 min practice we will do in 60 min but in 49 min asanas ended why?
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 453:
#   Rating: 3
#   Feedback:  patanjli is a very good teacher, but i didnt break a sweat at all, body was not warmed enough for the deep stretches
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 454:
#   Rating: 5
#   Feedback: Personal feedback was great
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 455:
#   Rating: 3
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 456:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 457:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 458:
#   Rating: 2.5
#   Feedback: This one was hard
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 459:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 460:
#   Rating: 5
#   Feedback: Holding the poses for the 10 count was difficult.  It’s not that I didn’t like it…just have not held poses for that long before.  Western yoga🙄
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 461:
#   Rating: 5
#   Feedback: Excellent!
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 462:
#   Rating: 4
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 463:
#   Rating: 4
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 464:
#   Rating: 3
#   Feedback:  My expectation from the session was to have sleep meditation as the name suggested and I felt the session was more for relaxation. The trainer was really good, maybe only that my expectation was different.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 465:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 466:
#   Rating: 5
#   Feedback: very informative
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 467:
#   Rating: 5
#   Feedback: Shruthi is my fav teacher.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 468:
#   Rating: 5
#   Feedback: I got what I needed
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 469:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 470:
#   Rating: 3
#   Feedback: There was a lot of technical difficulty
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 471:
#   Rating: 3
#   Feedback:  Since i never did yoga, i will join basic class !! hard for me to do this right. now
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 472:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 473:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 474:
#   Rating: 5
#   Feedback: loved it!!
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 475:
#   Rating: 4
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 476:
#   Rating: 5
#   Feedback: first time doing it and loved it! Sir and his instructions are just perfect. Thank you!
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 477:
#   Rating: 4
#   Feedback: I think that was a little too challenging for me.  I tried!
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 478:
#   Rating: 4
#   Feedback:  sometimes voice is very low, but overall its good.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 479:
#   Rating: 5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 480:
#   Rating: 1.5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Negative
#   Predicted Sentiment: Positive
#
# Feedback 481:
#   Rating: 4
#   Feedback: It was little difficult to understand all moves, also tght it was somewhat fast paced for new joiners. But the trainer was good
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 482:
#   Rating: 5
#   Feedback: Restorative yoga sessionof shakshi is good It would be good if we have restorative like this in weekends
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 483:
#   Rating: 3
#   Feedback: Instructions were good and voice was calming. Overall it would have been more relaxing without the sound disturbances - clanking background noises.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 484:
#   Rating: 5
#   Feedback: awesome class
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 485:
#   Rating: 5
#   Feedback: He is one of the best instructor
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 486:
#   Rating: 5
#   Feedback: Patanjali is one of the best
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 487:
#   Rating: 3
#   Feedback:  Most of the time teacher was not showing how to do the asanas, she was doing some asanas and just giving instructions for other asanas... For beginners it would be beneficial if she can do and show each and every asana
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 488:
#   Rating: 5
#   Feedback: So much care from Shvasa and all the team. Thank you Pradeep for sharing all your knowledge and experience.
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 489:
#   Rating: 5
#   Feedback: Wonderful feelings. Namaste!
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 490:
#   Rating: 5
#   Feedback: Construction of the class
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 491:
#   Rating: 5
#   Feedback: i loved the variation in the asanas
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 492:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 493:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 494:
#   Rating: 4.5
#   Feedback: I loved the classes
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 495:
#   Rating: 5
#   Feedback: Wonderful giving clear Instructions
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 496:
#   Rating: 3
#   Feedback:  There were internet issues .. not sure on who's side, but was not able to follow due to internet issues/
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Feedback 497:
#   Rating: 1
#   Feedback: internet connection was very unstable
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 498:
#   Rating: 1
#   Feedback: Video and audio not workimg
#   Actual Sentiment: Negative
#   Predicted Sentiment: Negative
#
# Feedback 499:
#   Rating: 5
#   Feedback: Excellent!
#   Actual Sentiment: Positive
#   Predicted Sentiment: Positive
#
# Overall Accuracy: 0.99
